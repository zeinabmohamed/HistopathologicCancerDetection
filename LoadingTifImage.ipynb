# %% [markdown]
# <a href="https://colab.research.google.com/github/zeinabmohamed/HistopathologicCancerDetection/blob/master/LoadingTifImage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# List all My drive sub dir's

# %%
import os
train_data_path = "/content/drive/My Drive/histopathologic-cancer-detection/train/"
train_items = os.listdir(train_data_path)
train_items_len =len(train_items)
print(train_items_len)

#print (train_items)
# Out:
# 21420

# %% [markdown]
# Test Load single Tif Image

# %%
# Load Tif image 
from PIL import Image
img = Image.open(train_data_path+"b61bcb7cb5095d17967d8446afcf60ae82e40a18.tif")
img #show image
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96 at 0x7F99EC5D7BE0>

# %% [markdown]
# Load all train data `<tif images>`

# %%
for each_image in train_items:
  if each_image.endswith(".tif"):
    #print (each_image)
    full_path = train_data_path + each_image
    #print (full_path)

# %%
import numpy as np
import imageio

# All Images (96, 96, 3) = 27648 
image_size = 96*96*3
train_items_matrix=np.zeros((train_items_len,image_size))  

for i in range(len(train_items)):
    imarray=imageio.imread(train_data_path +  train_items[i])
    imarray.size
    train_items_matrix[i,:]=imarray.reshape((1,image_size))

plt.imshow(train_items_matrix[1000,:].reshape(96,96,3)) #To Display it
